# %% [markdown]
# <a href="https://colab.research.google.com/github/Alejandroduoc/examendepartamentos/blob/main/Alejandro_rodriguez_pgy1121_004_v.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import datetime
departamentos = []
ganancias_ventas = {
    'A': 0,
    'B': 0,
    'C': 0,
    'D': 0

}

compradores = []
def iniciar():

    for piso in range(1, 11):
        pisos = []
        for i in range(4):
            departamento = {
                "DEP": chr(65 + i) + str(piso),
                'EST': '',
                'PRECIOV': 0

            }
            if i == 0:
                departamento['PRECIOV'] = 3800
            elif i == 1:
                departamento['PRECIOV'] = 3000
            elif i == 2:
                departamento['PRECIOV'] = 2800
            elif i == 3:
                departamento['PRECIOV'] = 3500


            pisos.append(departamento)
        departamentos.append(pisos)


def imprimir_departamentos():

    for piso in departamentos:
        for departamento in piso:
            estado_departamento = departamento['EST']
            if estado_departamento == '':
                print(departamento['DEP'], estado_departamento, "\033[1;32m"+"VENTA:", departamento['PRECIOV'], "UF"+ "\033[0m", end=" ")
            elif estado_departamento == 'X':
                print( "\033[1;31m" + departamento['DEP'], estado_departamento + "\033[0m","\033[1;33m"+ "vendido:", departamento['PRECIOV'], "UF" + "\033[0m", end=" ")


        print()
def validar_rut(rut):
    rut = rut.replace("-", "").replace(".", "")
    if len(rut) != 9:
        return False
    if not rut[:-1].isdigit():
        return False

    digito_verificador = rut[-1].upper()
    rut_numeros = list(map(int, rut[:-1]))

    multiplicador = 2
    suma = 0
    for i in range(len(rut_numeros)-1, -1, -1):
        suma += rut_numeros[i] * multiplicador
        multiplicador = (multiplicador + 1) % 8 or 2

    digito_calculado = 11 - (suma % 11)
    digito_calculado = str(digito_calculado) if digito_calculado != 10 else "K"

    return digito_calculado == digito_verificador
def mostrar_lista_compradores():
    print("\033[1;31m"+"Lista de compradores:" + "\033[0m")
    compradores_ordenados = sorted(compradores, key=lambda c: c['RUT'])
    for comprador in compradores_ordenados:
        print("Departamento:", comprador['DEP'])
        print("Nombre:", comprador['NOMBRE'])
        print("RUT:", comprador['RUT'])
        print("--------------------")

def estado():
   nombre_persona = input("Ingrese el nombre de la persona que realiza la compra o arriendo: ")
   if len(nombre_persona) < 4:
       print("El nombre debe tener mínimo 4 caracteres")
       return
   while True:
    rut = input("Ingrese el RUT de la persona que realiza la compra o arriendo: ")
    rut= rut.replace("-", "").replace(".", "")
    if validar_rut(rut):
      print("RUT válido")
      global ventas_totales

      imprimir_departamentos()
      while True:
          nomd = input("Ingrese el departamento a comprar: ")
          nombre_departamento = nomd.upper()
          encontrado = False
          for piso in departamentos:
              for departamento in piso:
                  if departamento['DEP'] == nombre_departamento:
                      encontrado = True
                      if departamento['EST'] == 'X':
                          print("El departamento No está disponible. Intente nuevamente.")
                          estado()
                      else:
                          while True:
                              compra = input("Presione [X] para confirmar la Venta ): ")
                              compra = compra.upper()
                              if compra == "X":

                                  nuevo_estado = compra
                                  departamento['EST'] = nuevo_estado
                                  print("El departamento", nombre_departamento, "Vendido:", "\033[1;31m" + departamento['EST'] + "\033[0m","la operación se ha realizado correctamente")
                                  ganancias_ventas[departamento['DEP'][0]] += departamento['PRECIOV']

                                  departamento['COMPRADOR'] = {
                                      'NOMBRE': nombre_persona,
                                      'RUT': rut
                                  }
                                  break


                              else:
                                print("Ingrese solo X")
                      break
          if encontrado:
              break
          else:
           print("El departamento", nombre_departamento, "no se encontró. Intente nuevamente.")
      break
    else:
     print("RUT no valido")

def mostrar_ventas_por_tipo():
    total_cantidad_vendida = 0
    total_ganancia = 0
    print("\033[1;31m"+"Ventas por tipo de departamento:" + "\033[0m")
    print("  Tipo   Cantidad   Total    ")
    for tipo, ganancia in ganancias_ventas.items():
        cantidad_vendida =round( ganancia / departamentos[0][0]['PRECIOV'])
        print("  ",tipo,"       ",cantidad_vendida,"     ", ganancia,"UF")
        total_cantidad_vendida += cantidad_vendida
        total_ganancia += ganancia

    print("Total:", total_cantidad_vendida,"Ganancia total:", total_ganancia, "UF")

def salir():
    hora_actual = datetime.datetime.now().strftime("%H:%M:%S")
    print("Saliendo del sistema,desarrolador Alejandro Rodriguez ,", hora_actual)
def main():
    iniciar()
    while True:
        print("\033[1;31m"+"                     --- Menú Casa Feliz ---" + "\033[0m")
        print("1. Comprar departamento ")
        print("2. Mostrar departamentos disponibles")
        print("3. Ver listado de compradores")
        print("4. Mostrar ventas de departamento")
        print("5. Salir")

        opcion = input("Ingrese el número de la opción deseada: ")

        if opcion == "1":
            estado()
        elif opcion == "2":
            imprimir_departamentos()
        elif opcion == "3":
            mostrar_lista_compradores()
        elif opcion == "4":
            mostrar_ventas_por_tipo()
        elif opcion == "5":
            salir()
            break
        else:
            print("Opción inválida. Por favor, ingrese un número válido.")


main()
# Out:
#                      --- Menú Casa Feliz ---
# 1. Comprar departamento
# 2. Mostrar departamentos disponibles
# 3. Ver listado de compradores
# 4. Mostrar ventas de departamento
# 5. Salir
# Ingrese el número de la opción deseada: 1
# Ingrese el nombre de la persona que realiza la compra o arriendo: asdbasdjas
# Ingrese el RUT de la persona que realiza la compra o arriendo: 176957611
# RUT válido
# A1  VENTA: 3800 UF B1  VENTA: 3000 UF C1  VENTA: 2800 UF D1  VENTA: 3500 UF
# A2  VENTA: 3800 UF B2  VENTA: 3000 UF C2  VENTA: 2800 UF D2  VENTA: 3500 UF
# A3  VENTA: 3800 UF B3  VENTA: 3000 UF C3  VENTA: 2800 UF D3  VENTA: 3500 UF
# A4  VENTA: 3800 UF B4  VENTA: 3000 UF C4  VENTA: 2800 UF D4  VENTA: 3500 UF
# A5  VENTA: 3800 UF B5  VENTA: 3000 UF C5  VENTA: 2800 UF D5  VENTA: 3500 UF
# A6  VENTA: 3800 UF B6  VENTA: 3000 UF C6  VENTA: 2800 UF D6  VENTA: 3500 UF
# A7  VENTA: 3800 UF B7  VENTA: 3000 UF C7  VENTA: 2800 UF D7  VENTA: 3500 UF
# A8  VENTA: 3800 UF B8  VENTA: 3000 UF C8  VENTA: 2800 UF D8  VENTA: 3500 UF
# A9  VENTA: 3800 UF B9  VENTA: 3000 UF C9  VENTA: 2800 UF D9  VENTA: 3500 UF
# A10  VENTA: 3800 UF B10  VENTA: 3000 UF C10  VENTA: 2800 UF D10  VENTA: 3500 UF
# Ingrese el departamento a comprar: a1
# Presione [X] para confirmar la Venta ): x
# El departamento A1 Vendido: X la operación se ha realizado correctamente
#                      --- Menú Casa Feliz ---
# 1. Comprar departamento
# 2. Mostrar departamentos disponibles
# 3. Ver listado de compradores
# 4. Mostrar ventas de departamento
# 5. Salir
# Ingrese el número de la opción deseada: 3
# Lista de compradores:
#                      --- Menú Casa Feliz ---
# 1. Comprar departamento
# 2. Mostrar departamentos disponibles
# 3. Ver listado de compradores
# 4. Mostrar ventas de departamento
# 5. Salir
# Ingrese el número de la opción deseada: 2
# A1 X vendido: 3800 UF B1  VENTA: 3000 UF C1  VENTA: 2800 UF D1  VENTA: 3500 UF
# A2  VENTA: 3800 UF B2  VENTA: 3000 UF C2  VENTA: 2800 UF D2  VENTA: 3500 UF
# A3  VENTA: 3800 UF B3  VENTA: 3000 UF C3  VENTA: 2800 UF D3  VENTA: 3500 UF
# A4  VENTA: 3800 UF B4  VENTA: 3000 UF C4  VENTA: 2800 UF D4  VENTA: 3500 UF
# A5  VENTA: 3800 UF B5  VENTA: 3000 UF C5  VENTA: 2800 UF D5  VENTA: 3500 UF
# A6  VENTA: 3800 UF B6  VENTA: 3000 UF C6  VENTA: 2800 UF D6  VENTA: 3500 UF
# A7  VENTA: 3800 UF B7  VENTA: 3000 UF C7  VENTA: 2800 UF D7  VENTA: 3500 UF
# A8  VENTA: 3800 UF B8  VENTA: 3000 UF C8  VENTA: 2800 UF D8  VENTA: 3500 UF
# A9  VENTA: 3800 UF B9  VENTA: 3000 UF C9  VENTA: 2800 UF D9  VENTA: 3500 UF
# A10  VENTA: 3800 UF B10  VENTA: 3000 UF C10  VENTA: 2800 UF D10  VENTA: 3500 UF
#                      --- Menú Casa Feliz ---
# 1. Comprar departamento
# 2. Mostrar departamentos disponibles
# 3. Ver listado de compradores
# 4. Mostrar ventas de departamento
# 5. Salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-bfb8ef0694e4> in <cell line: 174>()
#     172
#     173
# --> 174 main()
#
# <ipython-input-25-bfb8ef0694e4> in main()
#     155         print("5. Salir")
#     156
# --> 157         opcion = input("Ingrese el número de la opción deseada: ")
#     158
#     159         if opcion == "1":
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import datetime

departamentos = []
ganancias_ventas = {
    'A': 0,
    'B': 0,
    'C': 0,
    'D': 0
}

compradores = []

def iniciar():
    for piso in range(1, 11):
        pisos = []
        for i in range(4):
            departamento = {
                "DEP": chr(65 + i) + str(piso),
                'EST': '',
                'PRECIOV': 0
            }
            if i == 0:
                departamento['PRECIOV'] = 3800
            elif i == 1:
                departamento['PRECIOV'] = 3000
            elif i == 2:
                departamento['PRECIOV'] = 2800
            elif i == 3:
                departamento['PRECIOV'] = 3500
            pisos.append(departamento)
        departamentos.append(pisos)


def imprimir_departamentos():
    for piso in departamentos:
        for departamento in piso:
            estado_departamento = departamento['EST']
            if estado_departamento == '':
                print(departamento['DEP'], estado_departamento, "\033[1;32m"+"VENTA:", departamento['PRECIOV'], "UF"+ "\033[0m", end=" ")
            elif estado_departamento == 'X':
                print( "\033[1;31m" + departamento['DEP'], estado_departamento + "\033[0m","\033[1;33m"+ "vendido:", departamento['PRECIOV'], "UF" + "\033[0m", end=" ")
        print()


def validar_rut(rut):
    rut = rut.replace("-", "").replace(".", "")
    if len(rut) != 9:
        return False
    if not rut[:-1].isdigit():
        return False

    digito_verificador = rut[-1].upper()
    rut_numeros = list(map(int, rut[:-1]))

    multiplicador = 2
    suma = 0
    for i in range(len(rut_numeros)-1, -1, -1):
        suma += rut_numeros[i] * multiplicador
        multiplicador = (multiplicador + 1) % 8 or 2

    digito_calculado = 11 - (suma % 11)
    digito_calculado = str(digito_calculado) if digito_calculado != 10 else "K"

    return digito_calculado == digito_verificador


def mostrar_lista_compradores():
    print("\033[1;31m"+"Lista de compradores:" + "\033[0m")
    compradores_ordenados = sorted(compradores, key=lambda c: c['RUT'])
    for comprador in compradores_ordenados:
        print("Departamento:", comprador['DEP'])
        print("Nombre:", comprador['NOMBRE'])
        print("RUT:", comprador['RUT'])
        print("--------------------")


def estado():
    nombre_persona = input("Ingrese el nombre de la persona que realiza la compra o arriendo: ")
    if len(nombre_persona) < 4:
        print("El nombre debe tener mínimo 4 caracteres")
        return
    while True:
        rut = input("Ingrese el RUT de la persona que realiza la compra o arriendo: ")
        rut = rut.replace("-", "").replace(".", "")
        if validar_rut(rut):
            print("RUT válido")
            global ventas_totales

            imprimir_departamentos()
            while True:
                nomd = input("Ingrese el departamento a comprar: ")
                nombre_departamento = nomd.upper()
                encontrado = False
                for piso in departamentos:
                    for departamento in piso:
                        if departamento['DEP'] == nombre_departamento:
                            encontrado = True
                            if departamento['EST'] == 'X':
                                print("El departamento No está disponible. Intente nuevamente.")
                                estado()
                            else:
                                while True:
                                    compra = input("Presione [X] para confirmar la Venta: ")
                                    compra = compra.upper()
                                    if compra == "X":
                                        nuevo_estado = compra
                                        departamento['EST'] = nuevo_estado
                                        print("El departamento", nombre_departamento, "Vendido:", "\033[1;31m" + departamento['EST'] + "\033[0m","la operación se ha realizado correctamente")
                                        ganancias_ventas[departamento['DEP'][0]] += departamento['PRECIOV']

                                        compradores.append({
                                            'DEP': nombre_departamento,
                                            'NOMBRE': nombre_persona,
                                            'RUT': rut
                                        })
                                        break
                                    else:
                                        print("Ingrese solo X")
                            break
                if encontrado:
                    break
                else:
                    print("El departamento", nombre_departamento, "no se encontró. Intente nuevamente.")
            break
        else:
            print("RUT no válido")


def mostrar_ventas_por_tipo():
    total_cantidad_vendida = 0
    total_ganancia = 0
    print("\033[1;31m"+"Ventas por tipo de departamento:" + "\033[0m")
    print("  Tipo   Cantidad   Total    ")
    for tipo, ganancia in ganancias_ventas.items():
        cantidad_vendida = round(ganancia / departamentos[0][0]['PRECIOV'])
        print("  ", tipo, "       ", cantidad_vendida, "     ", ganancia, "UF")
        total_cantidad_vendida += cantidad_vendida
        total_ganancia += ganancia
    print("Total:", total_cantidad_vendida, "Ganancia total:", total_ganancia, "UF")


def salir():
    hora_actual = datetime.datetime.now().strftime("%H:%M:%S")
    print("Saliendo del sistema, desarrollado por Alejandro Rodriguez,", hora_actual)


def main():
    iniciar()
    while True:
        print("\033[1;31m"+"                     --- Menú Casa Feliz ---" + "\033[0m")
        print("1. Comprar departamento ")
        print("2. Mostrar departamentos disponibles")
        print("3. Ver listado de compradores")
        print("4. Mostrar ventas de departamento")
        print("5. Salir")

        opcion = input("Ingrese el número de la opción deseada: ")

        if opcion == "1":
            estado()
        elif opcion == "2":
            imprimir_departamentos()
        elif opcion == "3":
            mostrar_lista_compradores()
        elif opcion == "4":
            mostrar_ventas_por_tipo()
        elif opcion == "5":
            salir()
            break
        else:
            print("Opción inválida. Por favor, ingrese un número válido.")


main()
